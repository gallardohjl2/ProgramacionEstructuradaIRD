# %% [markdown]
# # Operaciones
#
# En esta área se realizan las operaciones aritméticas `básicas` - **Soy el primero**
#
# ```python
# for i in range(10):
#   valor = 10
# ```

# %%
suma = 4 + 2
resta = 4-2
multi = 4 * 2
div = 10 / 3
divEntera = 10//3
mod = 10 % 2
potencia = 10 ** 2

# %% [markdown]
# ## Generar Salida
#
# Mediante la utilización de un String literal se construye la salida
#
# ```python
#  numero = 10
#  salida = f'Salida de una sola linea {numero}'
#
#  salida = f```
#             Salida de varias lineas {numero}
#           ```
#
# ```

# %%
salida = f"""
    ===== Resultados de Operadores Aritmeticos
    La suma es: {suma}
             La Resta es: {resta}
             La Multiplicación: {multi}
             La División es: {div}
             La División Entera es: {divEntera}
             EL modulo es: {mod}
             La potencia es: {potencia} 
          """

print(salida)
# Out:
#     ===== Resultados de Operadores Aritmeticos
#     La suma es: 6
#              La Resta es: 2
#              La Multiplicación: 8
#              La División es: 3.3333333333333335
#              La División Entera es: 3
#              EL modulo es: 0
#              La potencia es: 100
